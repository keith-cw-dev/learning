# %%
Personal CSS Styling Guide
<link rel="stylesheet" href="styles.css"> - reference style sheet

# %%
Personal HTML Guide

Starter Boilerplate Code:
<html>

# %%
Personal JavaScript Guide

# %%
Personal Typescript Guide

# %%
Personal (Restful) API Guide (Creating and Calling)

# %%
Personal RDBMS Guide

# %%
Personal (CRUD) Database/SQL Guide
