# %%
# This is a Python script to generate a Jupyter Notebook structure for notes on memory management in C.
# Run this script to create a .ipynb file with the specified structure.

import json

notebook = {
    "cells": [
        {
            "cell_type": "markdown",
            "metadata": {},
            "source": [
                "# Memory Management in C\n",
                "\n",
                "This notebook contains notes and examples on memory management in C, including dynamic allocation, pointers, and best practices.\n",
                "\n",
                "## Sections:\n",
                "- Section 1: Introduction to Pointers\n",
                "- Section 2: Dynamic Memory Allocation (malloc)\n",
                "- Section 3: Freeing Memory (free)\n",
                "- Section 4: Memory Leaks\n",
                "- Section 5: Realloc\n",
                "- Section 6: Pointer Arithmetic\n",
                "- Section 7: Common Pitfalls\n",
                "- Section 8: Structs and Memory\n",
                "- Section 9: Arrays vs. Pointers\n",
                "- Section 10: Memory Alignment\n",
                "- Section 11: Advanced Topics (e.g., Valgrind)\n"
            ]
        }
    ] + [
        {
            "cell_type": "code",
            "metadata": {},
            "source": [
                "# Section {}: Placeholder for C code examples\n".format(i+1),
                "\n",
                "# Add your C code here\n"
            ],
            "execution_count": None,
            "outputs": []
        } for i in range(11)
    ],
    "metadata": {
        "kernelspec": {
            "display_name": "C",
            "language": "c",
            "name": "c"
        },
        "language_info": {
            "name": "c"
        }
    },
    "nbformat": 4,
    "nbformat_minor": 4
}

with open('memory_management_notes.ipynb', 'w') as f:
    json.dump(notebook, f, indent=1)
