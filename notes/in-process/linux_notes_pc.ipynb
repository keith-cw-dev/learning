# %% [markdown]
# Learning Goals:

# %% [markdown]
# - Understand the difference between shell and terminal
# - Learn how to navigate and use file system w/ CLI
# - Learn how to install software w/ CLI
# - Understand how to manage your PATH and env vars
# - Learn how to manage perms and execute programs

# %% [markdown]
# Terminal - "Terminal Emulator" - program that renders text on the screen to give commands. (render)
#
# Shell (ref as REPL) - program that runs terminal commands (interpret)
#
# REPL - Read. Eval. Print. Loop.
#
# To use variables, preface the variable name being called with $

# %%
stdout - >

stderr - 2>

stdin - read <variable to set input>

piping - |
- takes the stdout on left of pipe and inputs as stdin of program on right

ctrl + c
- interrupts a program by sending a signal interrupt (SIGINT)

grep -R "Bob" PATH_TO_TRANSACTIONS_DIR --exclude-dir="backups"
- reads all text/lines with "Bob" in them, excluding 'backups' directory.

wc -w (count by words) -l (count by lines)

kill <PID> (Process ID)
ps - process status 
aux (auxilery) - show all processes (including those owned by others) with
extra information

process status (ps) header
USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND

ls lists files and directories
grep searches for text
less displays text

top
- shows programs using the most resources
- can be used to diagnose performance issues
- potential kill scripts to delete resource-hogging processes?
- exit via 'q'

If your system is set up with a non-English locale, 
make sure that your printed output matches the expected by running this instead:

LANG=C top

package managers
- software tools to help install other software
- primary funtions:
    Downloading software from official sources
    Installing software
    Updating software
    Removing software
    Managing dependencies

apt (advanced package tool) - primary/most common package manager for Ubuntu
sudo apt update - updates adv pkg tool

MacOS Homebrew installation: /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"

curl.exe https://webi.ms/lsd | powershell

lsd --tree worldbanc/private
- shows contents at a given filepath in a folder tree
