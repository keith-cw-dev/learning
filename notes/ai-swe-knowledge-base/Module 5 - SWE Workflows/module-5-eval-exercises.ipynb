# %% [markdown]
# # Module 5 – Professional Software Engineering
#
# ## Part 5: AI Evaluation Scenarios
#
# For each scenario: choose the better model output, identify flaws, and justify your evaluation.

# %% [markdown]
# ### Scenario 1 – Deployment Pipeline Design
#
# **Prompt:** "Set up a deployment pipeline for a Node.js app."
#
# **Model A:** No tests, direct deploy to production.
#
# **Model B:** CI pipeline, tests, staging environment, rollback strategy.
#
# **Tasks:**
# - Evaluate production safety
# - Check completeness of workflow
# - Identify missing safeguards
# - Assess scalability of pipeline
# - Score engineering maturity

# %% [markdown]
# **Your evaluation:**
#
# Winner:
#
# Missing safeguards in Model A:
#
# Scores (safety / completeness / scalability / maturity):

# %% [markdown]
# ### Additional Scenarios
#
# Work through each of the following:
#
# - [ ] Evaluate Git workflows
# - [ ] Review CI/CD configurations
# - [ ] Assess Dockerfile correctness
# - [ ] Compare deployment strategies
# - [ ] Identify security risks in DevOps setups
# - [ ] Evaluate architecture decisions

# %% [markdown]
# **Your notes on additional scenarios:**
