# %% [markdown]
# # Module 5 – Professional Software Engineering
#
# ## Part 4: Debugging Lab
#
# For each scenario: identify the root cause, explain why it happens, and describe the fix.

# %% [markdown]
# ### 1. Why did this CI pipeline fail only in production?
#
# **Root cause:**
#
# **Fix:**

# %% [markdown]
# ### 2. Why is Docker build caching breaking?
#
# **Root cause:**
#
# **Fix:**
#
# ```dockerfile
# # Fixed Dockerfile layer order here
# ```

# %% [markdown]
# ### 3. Why are environment variables undefined in deployment?
#
# **Root cause:**
#
# **Fix:**

# %% [markdown]
# ### 4. Why did a merge introduce a regression?
#
# **Root cause:**
#
# **Fix / prevention:**

# %% [markdown]
# ### 5. Why is rollback not restoring correct state?
#
# **Root cause:**
#
# **Fix:**

# %% [markdown]
# ### 6. Why are logs missing in production?
#
# **Root cause:**
#
# **Fix:**

# %% [markdown]
# ### 7. Why is this Git history corrupted?
#
# **Root cause:**
#
# **Fix:**
#
# ```bash
# # Recovery commands here
# ```

# %% [markdown]
# ### 8. Why is deployment inconsistent across environments?
#
# **Root cause:**
#
# **Fix:**

# %% [markdown]
# ### 9. Why are tests passing locally but failing in CI?
#
# **Root cause:**
#
# **Fix:**

# %% [markdown]
# ### 10. Why is the build artifact incomplete?
#
# **Root cause:**
#
# **Fix:**
