# %% [markdown]
# # Module 5 – Professional Software Engineering
#
# ## Part 3: Coding & Engineering Exercises
#
# ### Each exercise includes:
#
# - Workflow correctness
# - Maintainability
# - Risk analysis
# - Production safety
# - Debugging readiness

# %% [markdown]
# ### Exercise 1 – Initialize a Git repo with feature branching
#
# ```bash
# # Your solution here
# ```

# %% [markdown]
# ### Exercise 2 – Resolve a complex merge conflict scenario
#
# **Scenario:**
#
# **Resolution approach:**

# %% [markdown]
# ### Exercise 3 – Create a CI pipeline for a Node.js project
#
# ```yaml
# # Your pipeline config here (e.g. GitHub Actions)
# ```

# %% [markdown]
# ### Exercise 4 – Write a Dockerfile for a full-stack app
#
# ```dockerfile
# # Your Dockerfile here
# ```

# %% [markdown]
# ### Exercise 5 – Optimize a slow build pipeline
#
# **Problem identified:**
#
# **Solution:**
#
# ```yaml
# # Optimized config here
# ```

# %% [markdown]
# ### Exercise 6 – Set up environment configs for dev/staging/prod
#
# ```bash
# # Your solution here
# ```

# %% [markdown]
# ### Exercise 7 – Add logging middleware to an API
#
# ```js
# // Your solution here
# ```

# %% [markdown]
# ### Exercise 8 – Design a modular backend architecture
#
# **Folder structure:**
#
# **Reasoning:**

# %% [markdown]
# ### Exercise 9 – Simulate a failed deployment and rollback
#
# **Failure scenario:**
#
# **Rollback steps:**

# %% [markdown]
# ### Exercise 10 – Refactor a monolithic backend into modules
#
# **Before (monolith):**
#
# **After (modular):**
