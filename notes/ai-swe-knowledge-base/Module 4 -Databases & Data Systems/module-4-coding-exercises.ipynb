# %% [markdown]
# # Module 4 – Databases, Data Modeling & System Design
#
# ## Part 3: Coding Exercises
#
# ### Each exercise includes:
#
# - Schema correctness
# - Query efficiency
# - Scalability considerations
# - Data integrity checks
# - Edge cases

# %% [markdown]
# ### Exercise 1 – Design a users + posts schema
#
# ```sql
# -- Your solution here
# ```

# %% [markdown]
# ### Exercise 2 – Write SQL joins for a blog system
#
# ```sql
# -- Your solution here
# ```

# %% [markdown]
# ### Exercise 3 – Implement pagination query
#
# ```sql
# -- Your solution here
# ```

# %% [markdown]
# ### Exercise 4 – Design a many-to-many relationship (users ↔ roles)
#
# ```sql
# -- Your solution here
# ```

# %% [markdown]
# ### Exercise 5 – Build a schema for messaging system
#
# ```sql
# -- Your solution here
# ```

# %% [markdown]
# ### Exercise 6 – Optimize a slow query
#
# ```sql
# -- Your solution here
# ```

# %% [markdown]
# ### Exercise 7 – Normalize a poorly designed schema
#
# ```sql
# -- Your solution here
# ```

# %% [markdown]
# ### Exercise 8 – Write aggregation queries for analytics
#
# ```sql
# -- Your solution here
# ```

# %% [markdown]
# ### Exercise 9 – Design audit logging tables
#
# ```sql
# -- Your solution here
# ```

# %% [markdown]
# ### Exercise 10 – Convert SQL schema to NoSQL model (conceptual)
#
# **Your reasoning:**
