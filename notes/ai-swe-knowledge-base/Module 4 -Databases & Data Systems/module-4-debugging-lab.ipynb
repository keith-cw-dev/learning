# %% [markdown]
# # Module 4 – Databases, Data Modeling & System Design
#
# ## Part 4: Debugging Lab
#
# For each scenario: identify the root cause, explain why it happens, and write a fix.

# %% [markdown]
# ### 1. Why is this JOIN duplicating rows?
#
# **Root cause:**
#
# **Fix:**
#
# ```sql
# -- Broken query / fixed query here
# ```

# %% [markdown]
# ### 2. Why is this query slow at scale?
#
# **Root cause:**
#
# **Fix:**
#
# ```sql
# -- Broken query / fixed query here
# ```

# %% [markdown]
# ### 3. Why are inserts failing intermittently?
#
# **Root cause:**
#
# **Fix:**
#
# ```sql
# -- Broken query / fixed query here
# ```

# %% [markdown]
# ### 4. Why is data inconsistent across tables?
#
# **Root cause:**
#
# **Fix:**
#
# ```sql
# -- Schema or query fix here
# ```

# %% [markdown]
# ### 5. Why is this transaction partially applying?
#
# **Root cause:**
#
# **Fix:**
#
# ```sql
# -- Broken query / fixed query here
# ```

# %% [markdown]
# ### 6. Why is pagination skipping records?
#
# **Root cause:**
#
# **Fix:**
#
# ```sql
# -- Broken query / fixed query here
# ```

# %% [markdown]
# ### 7. Why is the index not being used?
#
# **Root cause:**
#
# **Fix:**
#
# ```sql
# -- Broken query / fixed query here
# ```

# %% [markdown]
# ### 8. Why is this schema causing update anomalies?
#
# **Root cause:**
#
# **Fix:**
#
# ```sql
# -- Schema redesign here
# ```

# %% [markdown]
# ### 9. Why are NULL values breaking logic?
#
# **Root cause:**
#
# **Fix:**
#
# ```sql
# -- Broken query / fixed query here
# ```

# %% [markdown]
# ### 10. Why is this NoSQL model causing duplication?
#
# **Root cause:**
#
# **Fix / redesign:**
