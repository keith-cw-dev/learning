# %% [markdown]
# # Module 4 – Databases, Data Modeling & System Design
#
# ## Part 7: 50-Question Final Assessment
#
# Each question includes: ideal solution, common misconceptions, subtle failure cases, and evaluator reasoning expectations.

# %% [markdown]
# ### Questions 1–15: Conceptual Understanding
#
# Topics covered:
# - Relational models
# - Normalization
# - SQL basics
# - Joins
# - Indexing
# - Transactions

# %% [markdown]
# **Your answers (Q1–15):**

# %% [markdown]
# ### Questions 16–25: Query Reading & Output Prediction
#
# Topics covered:
# - JOIN behavior
# - Aggregation results
# - Filtering logic
# - NULL handling
# - Grouping behavior

# %% [markdown]
# **Your answers (Q16–25):**

# %% [markdown]
# ### Questions 26–35: Debugging & Performance Issues
#
# Topics covered:
# - Slow queries
# - Incorrect joins
# - Missing indexes
# - Transaction bugs
# - Schema design flaws

# %% [markdown]
# **Your answers (Q26–35):**

# %% [markdown]
# ### Questions 36–45: Schema & Query Design
#
# Topics covered:
# - Design database schemas
# - Write SQL queries
# - Optimize structures
# - Convert requirements into relational models
# - Fix poor schema designs

# %% [markdown]
# **Your answers (Q36–45):**

# %% [markdown]
# ### Questions 46–50: AI Evaluation Scenarios
#
# - Compare two database schemas for correctness and scalability
# - Evaluate SQL queries generated by AI
# - Review indexing decisions
# - Identify normalization issues in AI-generated designs
# - Write evaluator feedback on data integrity and system correctness

# %% [markdown]
# **Your answers (Q46–50):**
