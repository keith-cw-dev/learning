# %% [markdown]
# # Module 1 – JavaScript & TypeScript Foundations
#
# ## Part 7: 50-Question Final Assessment
#
# Each question includes: a detailed solution, explanations of common misconceptions, and discussion of why incorrect options are tempting.

# %% [markdown]
# ### Questions 1–15: Conceptual Understanding
#
# Topics covered:
# - Variables and memory
# - Scope and closures
# - The `this` keyword
# - Functions and higher-order patterns
# - Objects and prototypes
# - Asynchronous JavaScript
# - Modules
# - TypeScript fundamentals

# %% [markdown]
# **Your answers (Q1–15):**

# %% [markdown]
# ### Questions 16–25: Code Reading and Output Prediction
#
# Topics covered:
# - Hoisting behavior
# - Closure capture
# - Event loop ordering (microtasks vs macrotasks)
# - `this` binding in different contexts
# - TypeScript type inference

# %% [markdown]
# **Your answers (Q16–25):**

# %% [markdown]
# ### Questions 26–35: Debugging and Bug Fixing
#
# Topics covered:
# - Closure returning wrong value
# - Stale `this` in callbacks
# - Mutated shared objects
# - Promise chains not resolving
# - TypeScript narrowing failures
# - Circular dependencies

# %% [markdown]
# **Your answers (Q26–35):**

# %% [markdown]
# ### Questions 36–45: TypeScript Design and Implementation
#
# Topics covered:
# - Generics
# - Utility types
# - Discriminated unions
# - Type narrowing
# - Interface vs type alias tradeoffs
# - `unknown` vs `any` vs `never`

# %% [markdown]
# **Your answers (Q36–45):**

# %% [markdown]
# ### Questions 46–50: AI Evaluation Scenarios
#
# Requiring written justification:
#
# - Evaluate two explanations of closures and justify which is more accurate.
# - Identify the factual error in an AI-generated description of the event loop.
# - Compare two TypeScript implementations and choose the more maintainable one.
# - Assess an AI explanation of `this` binding for correctness and clarity.
# - Write evaluator feedback on an AI-generated async/await implementation.

# %% [markdown]
# **Your answers (Q46–50):**
