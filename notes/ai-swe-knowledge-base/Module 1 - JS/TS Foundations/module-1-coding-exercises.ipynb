# %% [markdown]
# # Module 1 – JavaScript & TypeScript Foundations
#
# ## Part 3: Coding Exercises
#
# ### Each exercise should include:
#
# - Time complexity
# - Space complexity
# - Edge cases
# - Refactoring opportunities

# %% [markdown]
# ### Exercise 1 – Implement your own map()
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 2 – Implement your own filter()
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 3 – Implement your own reduce()
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 4 – Write a debounce function
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 5 – Write a throttle function
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 6 – Build a memoization helper
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 7 – Deep clone an object without structuredClone
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 8 – Flatten a nested array
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 9 – Group objects by property
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 10 – Implement a simple event emitter
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**
