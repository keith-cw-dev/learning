# %% [markdown]
# # Module 1 – JavaScript & TypeScript Foundations
#
# ## Part 4: Debugging Lab
#
# For each scenario: identify the root cause, explain why it happens, and write a fix.

# %% [markdown]
# ### 1. Why does this closure return the wrong value?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 2. Why is this async function hanging?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 3. Why is this undefined?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 4. Why is this Promise never resolving?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 5. Why does TypeScript infer never here?
#
# **Root cause:**
#
# **Fix:**
#
# ```ts
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 6. Why did this destructuring assignment fail?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 7. Why did this mutation affect another object?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 8. Why is this generic too restrictive?
#
# **Root cause:**
#
# **Fix:**
#
# ```ts
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 9. Why does this union type not narrow?
#
# **Root cause:**
#
# **Fix:**
#
# ```ts
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 10. Why is this module causing a circular dependency?
#
# **Root cause:**
#
# **Fix / restructure:**
