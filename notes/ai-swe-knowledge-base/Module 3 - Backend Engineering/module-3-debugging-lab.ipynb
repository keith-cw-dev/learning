# %% [markdown]
# # Module 3 – Backend Engineering
#
# ## Part 4: Debugging Lab
#
# For each scenario: identify the root cause, explain why it happens, and write a fix.

# %% [markdown]
# ### 1. Why is this API route never hit?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 2. Why is authentication failing intermittently?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 3. Why are sessions not persisting?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 4. Why is JWT verification failing?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 5. Why is this middleware blocking all requests?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 6. Why is this database query slow?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 7. Why are WebSocket events duplicating?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 8. Why is CORS blocking valid requests?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 9. Why is this async route crashing silently?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 10. Why is this transaction not committing?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```
