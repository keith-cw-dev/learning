# %% [markdown]
# # Module 3 – Backend Engineering
#
# ## Part 5: AI Evaluation Scenarios
#
# For each scenario: choose the better model output, identify flaws, and justify your evaluation.

# %% [markdown]
# ### Scenario 1 – Login API Security
#
# **Prompt:** "Build a login API."
#
# **Model A:** Stores passwords in plaintext.
#
# **Model B:** Uses hashing, sessions, proper error handling, validation.
#
# **Tasks:**
# - Identify security flaws
# - Evaluate correctness
# - Check API design quality
# - Assess scalability
# - Score clarity and maintainability

# %% [markdown]
# **Your evaluation:**
#
# Winner:
#
# Security flaws identified:
#
# Scores (correctness / security / clarity / maintainability):

# %% [markdown]
# ### Additional Scenarios
#
# Work through each of the following:
#
# - [ ] JWT vs session tradeoffs
# - [ ] REST API design evaluation
# - [ ] Database schema review
# - [ ] WebSocket implementation critique
# - [ ] Middleware chain evaluation
# - [ ] Error handling completeness
# - [ ] Rate limiting design

# %% [markdown]
# **Your notes on additional scenarios:**
