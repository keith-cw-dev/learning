# %% [markdown]
# # Module 6 – Algorithms & Problem Solving
#
# ## Part 3: Coding Exercises
#
# ### Each exercise includes:
#
# - Time complexity
# - Space complexity
# - Edge cases
# - Alternative approaches
# - Optimization discussion

# %% [markdown]
# ### Exercise 1 – Two Sum variations
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 2 – Longest substring without repeating characters
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 3 – Valid parentheses checker
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 4 – Binary search variations
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 5 – Reverse linked list
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 6 – Detect cycle in linked list
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 7 – Lowest common ancestor
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 8 – Merge intervals
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 9 – Word search (grid DFS)
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**

# %% [markdown]
# ### Exercise 10 – Coin change (DP)
#
# ```js
# // Your solution here
# ```
#
# **Time complexity:** O(?)
# **Space complexity:** O(?)
# **Edge cases:**
