# %% [markdown]
# # Module 6 – Algorithms & Problem Solving
#
# ## Part 4: Debugging Lab
#
# For each scenario: identify the root cause, explain why it happens, and write a fix.

# %% [markdown]
# ### 1. Why does this recursion overflow?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 2. Why is this DP solution returning incorrect results?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 3. Why is binary search skipping valid answers?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 4. Why is DFS revisiting nodes?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 5. Why is this greedy solution failing edge cases?
#
# **Root cause:**
#
# **Counterexample:**
#
# **Fix / alternative approach:**

# %% [markdown]
# ### 6. Why is this hash map logic incorrect?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 7. Why is sorting breaking expected order logic?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 8. Why is this solution O(n²) unexpectedly?
#
# **Root cause:**
#
# **Optimized approach:**
#
# ```js
# // Optimized solution here
# ```

# %% [markdown]
# ### 9. Why is memoization not working?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 10. Why is this tree traversal missing nodes?
#
# **Root cause:**
#
# **Fix:**
#
# ```js
# // Broken code / fixed code here
# ```
