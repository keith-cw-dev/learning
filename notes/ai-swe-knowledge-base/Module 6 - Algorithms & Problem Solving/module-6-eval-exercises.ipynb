# %% [markdown]
# # Module 6 – Algorithms & Problem Solving
#
# ## Part 5: AI Evaluation Scenarios
#
# For each scenario: choose the better model output, identify flaws, and justify your evaluation.

# %% [markdown]
# ### Scenario 1 – Longest Palindrome Substring
#
# **Prompt:** "Find the longest palindrome substring."
#
# **Model A:** Brute force O(n³).
#
# **Model B:** Expands from center, O(n²), with optimized reasoning.
#
# **Tasks:**
# - Compare correctness
# - Evaluate efficiency
# - Identify missing edge cases
# - Assess reasoning clarity
# - Judge whether explanation matches implementation

# %% [markdown]
# **Your evaluation:**
#
# Winner:
#
# Complexity comparison:
#
# Missing edge cases:
#
# Scores (correctness / efficiency / clarity / explanation match):

# %% [markdown]
# ### Additional Scenarios
#
# Work through each of the following:
#
# - [ ] Compare greedy vs DP solutions
# - [ ] Evaluate recursion correctness
# - [ ] Identify hidden inefficiencies
# - [ ] Detect incorrect complexity claims
# - [ ] Evaluate AI-generated explanations of algorithms

# %% [markdown]
# **Your notes on additional scenarios:**
