# %% [markdown]
# This notebook is a collection of real-world debugging scenarios.
#
# Goal:
# Train systematic debugging intuition for backend, frontend, and full-stack systems.
#
# Focus areas:
# - Reproducing bugs
# - Isolating root causes
# - Identifying misleading signals
# - Reasoning under incomplete information
# - Evaluating AI-generated “fixes”

# %% [markdown]
# Debugging Framework:
#
# 1. What is the expected behavior?
# 2. What is the actual behavior?
# 3. What changed recently?
# 4. Where is the first point of failure?
# 5. What assumptions does the code make?
# 6. What would I check first in production logs?
# 7. What is the smallest reproduction case?

# %% [markdown]
# Template:
#
# Case Title:
# System Type:
# Symptom:
# Environment:
#
# ---
#
# Observed Behavior:
# Expected Behavior:
#
# ---
#
# Hypotheses:
# - Hypothesis 1:
# - Hypothesis 2:
# - Hypothesis 3:
#
# ---
#
# Debugging Steps:
# 1.
# 2.
# 3.
#
# ---
#
# Root Cause:
#
# ---
#
# Fix:
#
# ---
#
# Prevention Strategy:

# %% [markdown]
# Categories:
#
# - Async / race conditions
# - State management bugs
# - API / backend failures
# - Database inconsistencies
# - React re-render issues
# - TypeScript inference issues
# - Deployment / CI failures
# - Memory leaks
# - Authentication failures

# %% [markdown]
# AI Debugging Evaluation Checklist:
#
# - Did the model identify the correct root cause?
# - Did it jump to conclusions?
# - Did it hallucinate APIs or logs?
# - Did it fix symptom instead of cause?
# - Did it consider edge cases?
