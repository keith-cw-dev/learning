# %% [markdown]
# # Module 2 – React & React Native Engineering
#
# ## Part 5: AI Evaluation Scenarios
#
# For each scenario: choose the better model output, identify flaws, and justify your evaluation.

# %% [markdown]
# ### Scenario 1 – Performance Optimization
#
# **Prompt:** "Optimize this React component."
#
# **Model A:** Wraps everything in `useMemo` and `useCallback`.
#
# **Model B:** Identifies the expensive computation, memoizes only that portion, and explains why.
#
# **Tasks:**
# - Choose the better solution.
# - Identify unnecessary optimizations.
# - Discuss readability.
# - Evaluate maintainability.
# - Score correctness, performance, clarity, and instruction following.

# %% [markdown]
# **Your evaluation:**
#
# Winner:
#
# Reasoning:
#
# Scores (correctness / performance / clarity / instruction following):

# %% [markdown]
# ### Additional Scenarios
#
# Work through each of the following. For each: identify which model wins, explain why, and note what the losing model got wrong.
#
# - [ ] Choosing between Context and React Query.
# - [ ] Reviewing React Native layouts.
# - [ ] Evaluating accessibility improvements.
# - [ ] Identifying stale closure bugs.
# - [ ] Reviewing custom hooks.
# - [ ] Assessing component architecture.

# %% [markdown]
# **Your notes on additional scenarios:**
