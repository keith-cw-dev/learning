# %% [markdown]
# # Module 2 – React & React Native Engineering
#
# ## Part 4: Debugging Lab
#
# For each scenario: identify the root cause, explain why it happens, and write a fix.

# %% [markdown]
# ### 1. Why is this component re-rendering endlessly?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 2. Why isn't useEffect firing?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 3. Why is useEffect firing too often?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 4. Why is state stale inside this callback?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 5. Why is useMemo not improving performance?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 6. Why does this FlatList lag?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 7. Why isn't navigation updating correctly?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 8. Why is Context causing unnecessary renders?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 9. Why isn't React Query refetching?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```

# %% [markdown]
# ### 10. Why is this custom hook violating the Rules of Hooks?
#
# **Root cause:**
#
# **Fix:**
#
# ```jsx
# // Broken code / fixed code here
# ```
