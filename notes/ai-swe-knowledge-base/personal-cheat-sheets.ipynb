# %% [markdown]
# This notebook is a high-signal reference system for fast recall.
#
# It contains:
# - mental models
# - common pitfalls
# - patterns
# - decision frameworks
# - debugging heuristics
# - evaluation rubrics
#
# Goal:
# Reduce cognitive load during coding, interviews, and AI evaluation tasks.

# %% [markdown]
# React:
# - UI = function(state)
#
# Backend:
# - API = state machine + validation layer
#
# Database:
# - truth storage system
#
# Algorithms:
# - pattern recognition under constraints

# %% [markdown]
# When choosing state management:
# - local state → UI-only
# - context → shared lightweight state
# - react query → server state
# - redux → only complex global orchestration

# %% [markdown]
# If React re-render bug:
# → check state mutation
# → check dependency arrays
# → check prop identity
#
# If API bug:
# → check middleware
# → check async handling
# → check request shape

# %% [markdown]
# Complexity Cheat Sheet:
#
#
# O(1) → hash map lookup
# O(log n) → binary search
# O(n) → single pass
# O(n log n) → sorting
# O(n²) → nested loops

# %% [markdown]
# When evaluating AI output:
#
# Correctness:
# - Does it actually work?
#
# Reasoning:
# - Does explanation match code?
#
# Completeness:
# - Are edge cases handled?
#
# Safety:
# - Any security risks?
#
# Hallucinations:
# - Any fake APIs or incorrect claims?

# %% [markdown]
# Common Pitfalls:
#
# React:
# - stale closures
# - unnecessary re-renders
#
# Backend:
# - missing error handling
# - unsafe auth logic
#
# DB:
# - missing indexes
# - duplicated data models
#
# JS:
# - async confusion
# - reference vs value bugs

# %% [markdown]
# Architecture Patterns
#
# Go-To's:
#
# Debounce:
# - timeout reset pattern
#
# Throttle:
# - timestamp gating
#
# Memoization:
# - cache by input key
#
# Pagination:
# - limit + offset or cursor-based
