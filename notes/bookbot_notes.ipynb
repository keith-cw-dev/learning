# %%
with open(path_to_file) as f:
    # do something with f (the file) here

- with block being used to open a file.

# f is a file object
file_contents = f.read()
- read file contents into a string
