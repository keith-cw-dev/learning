# %%
installing golang

curl -sS https://webi.sh/golang | sh

installing github

curl -sS https://webi.sh/gh | sh

- quick troubleshoot:
    # For Linux/WSL
echo 'export PATH=$PATH:$HOME/.local/opt/go/bin' >> ~/.bashrc
# next, reload your shell configuration
source ~/.bashrc

git version

installing git:
sudo apt update
sudo apt install software-properties-common # enables add-apt-repository command
sudo add-apt-repository ppa:git-core/ppa
sudo apt install git

configuration for starting projects:
mkdir <dir name>
git init

git status

staging:
git add <path-to-file | pattern>

commit (with message):
git commit -m "your message here"

git log shows:
- Who made a commit
- When the commit was made
- What was changed

git log (shows commit hash and commit tracking):
git --no-pager log -n 10

xxd for hexadecimal convert of file(s)

to see the contents of a commit:
git cat-file -p <hash>

git config set --global (or --local) user.name "value"
- to set section.key values in config

git config get <key>:
- to retrieve section.key keyvalues

git config list
- lists all config values

git config unset section.value
- removes set value for section.value key value

git config unset --all section.value
- clears all instances of a key

git config set --append section.value
- sets a section.value key value and allows 
multiple instances of same section key with varying key values

git config remove-section <section>
- removes the entirety of a section in git config

writing multiple lines to a file:
echo "I am your father" >> webflyx/quotes/starwars.md
echo "Do or do not. There is no try" >> webflyx/quotes/starwars.md
echo "I've got a bad feeling about this" >> webflyx/quotes/starwars.md

echo "May thy knife chip and shatter" >> webflyx/quotes/dune.md
echo "A Great Man Doesn't Seek To Lead. He's Called To It." >> webflyx/quotes/dune.md
echo "An Animal Caught In A Trap Will Gnaw Off Its Own Leg To Escape. What Will You Do?" >> webflyx/quotes/dune.md
echo "When Is A Gift Not A Gift?" >> webflyx/quotes/dune.md

system: /etc/gitconfig, a file that configures Git for all users on the system
global: ~/.gitconfig, a file that configures Git for all projects of a user
local: .git/config, a file that configures Git for a specific project
worktree: .git/config.worktree, a file that configures Git for part of a project

-- global is primarily used
-- local is usually for project specific configures
- sometimes worktree configs will need to be utilized, but rare

git branch -m oldname newname
- branch renaming

README - explains what your project is and how to run it
