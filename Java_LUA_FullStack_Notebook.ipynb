# %% [markdown]
# # 📘 Java, LUA, and Full-Stack Learning Notebook
# This Jupyter Notebook serves as a structured guide for tracking your learning journey in Java, LUA, Full Stack Development, and Cloud Engineering.
#
# ### **How to Use This Notebook**
# - 📌 Write your notes and insights in each section.
# - ✅ Use checkboxes `[ ]` for tracking completed concepts.
# - 🚀 Run the code cells for interactive learning.

# %% [markdown]
# ## **Java Learning Notes**
# ### ✅ **Core Java**
# - [ ] Object-Oriented Programming (OOP)
# - [ ] Collections Framework
# - [ ] Multithreading & Concurrency
#
# ### ✅ **Advanced Java**
# - [ ] Networking & Sockets
# - [ ] Reflection API & Annotations
# - [ ] Design Patterns
#
# ### 🚀 **Code Snippets**

# %%
class HelloWorld {
    public static void main(String[] args) {
        System.out.println("Hello, Java!");
    }
}

# %% [markdown]
# ## **LUA Learning Notes**
# ### ✅ **Basic LUA**
# - [ ] Variables & Data Types
# - [ ] Control Structures (Loops, If-Else)
# - [ ] Functions & Tables
#
# ### ✅ **Advanced LUA**
# - [ ] Metatables & Object-Oriented LUA
# - [ ] Coroutines & Asynchronous Programming
#
# ### 🚀 **Code Snippets**

# %%
print("Hello, LUA!")
local name = "Keefy"
print("Welcome, " .. name)

# %% [markdown]
# ## **Full-Stack Development Notes**
# ### ✅ **Backend with Spring Boot**
# - [ ] REST APIs
# - [ ] Spring Security (JWT, OAuth2)
# - [ ] Database & ORM (JPA, Hibernate)
#
# ### ✅ **Frontend (React/Angular)**
# - [ ] React.js / Angular Components
# - [ ] State Management (Redux, Services)
# - [ ] API Integration

# %% [markdown]
# ## **Cloud & DevOps Notes**
# ### ✅ **Cloud Deployment**
# - [ ] Docker & Kubernetes
# - [ ] CI/CD Pipelines (Jenkins, GitHub Actions)
# - [ ] AWS (Elastic Beanstalk, RDS, Lambda)
#
# ### 🚀 **Deployment Checklist**
# - [ ] Deploy Java API on Cloud
# - [ ] Containerize Microservices with Docker
